# %%
import os
import re
import gzip
import shutil
import pandas as pd

# %%
## Test if index column needs to be removed

df1 = pd.read_csv('/gpfs/project/anste145/input_files/buckeye_data/updated_eventfiles/s01.tsv', 
                  low_memory = True, 
                  dtype = ({'outcomes':'category'}), 
                  engine = 'c',
                  sep = '\t')
df1
df1.drop(columns='Unnamed: 0')
# --> it does
# Out:
#                                                    cues   outcomes
# 0                        c.i'm_y.ow_y.key_s.ow_s.k_s.ey       okay
# 1                         c.okay_c.lived_y.ihm_s.ih_s.m        i'm
# 2                   c.i'm_c.in_y.layvd_s.l_s.ay_s.v_s.d      lived
# 3                     c.lived_c.columbus_y.ihn_s.ih_s.n         in
# 4     c.in_c.my_y.kah_y.lahm_y.bahs_s.k_s.ah_s.l_s.a...   columbus
# 5                    c.columbus_c.entire_y.may_s.m_s.ay         my
# 6     c.my_c.life_y.ihn_y.tay_y.er_s.ih_s.n_s.t_s.ay...     entire
# 7                 c.entire_c.thirty_y.layf_s.l_s.ay_s.f       life
# 8         c.life_c.four_y.ther_y.diy_s.th_s.er_s.d_s.iy     thirty
# 9                  c.thirty_c.years_y.faor_s.f_s.ao_s.r       four
# 10               c.four_c.born_y.yihrz_s.y_s.ih_s.r_s.z      years
# 11               c.years_c.and_y.baorn_s.b_s.ao_s.r_s.n       born
# 12                  c.born_c.raised_y.aend_s.ae_s.n_s.d        and
# 13                  c.and_c.on_y.reyzd_s.r_s.ey_s.z_s.d     raised
# 14                        c.raised_c.the_y.aan_s.aa_s.n         on
# 15                         c.on_c.west_y.dhah_s.dh_s.ah        the
# 16                c.the_c.side_y.wehst_s.w_s.eh_s.s_s.t       west
# 17                      c.west_c.of_y.sayd_s.s_s.ay_s.d       side
# 18                     c.side_c.columbus_y.ahv_s.ah_s.v         of
# 19    c.of_c.i'm_y.kah_y.lahm_y.bahs_s.k_s.ah_s.l_s....   columbus
# 20                        c.columbus_c.a_y.ihm_s.ih_s.m        i'm
# 21                               c.i'm_c.it's_y.ah_s.ah          a
# 22                       c.a_c.kind_y.ihts_s.ih_s.t_s.s       it's
# 23                 c.it's_c.of_y.kaynd_s.k_s.ay_s.n_s.d       kind
# 24                            c.kind_c.a_y.ahv_s.ah_s.v         of
# 25                              c.of_c.unique_y.ah_s.ah          a
# 26    c.a_c.position_y.yuw_y.niyk_s.y_s.uw_s.n_s.iy_s.k     unique
# 27    c.unique_c.i_y.pah_y.zih_y.shahn_s.p_s.ah_s.z_...   position
# 28                         c.position_c.guess_y.ay_s.ay          i
# 29                        c.i_c.i'm_y.gehs_s.g_s.eh_s.s      guess
# ...                                                 ...        ...
# 4506                           c.to_c.to_y.gow_s.g_s.ow         go
# 4507                         c.go_c.pray_y.tah_s.t_s.ah         to
# 4508                      c.to_c.to_y.prey_s.p_s.r_s.ey       pray
# 4509                         c.pray_c.be_y.tah_s.t_s.ah         to
# 4510                         c.to_c.with_y.biy_s.b_s.iy         be
# 4511                   c.be_c.his_y.wihdh_s.w_s.ih_s.dh       with
# 4512              c.with_c.family_y.hhihz_s.hh_s.ih_s.z        his
# 4513  c.his_c.and_y.fae_y.mah_y.liy_s.f_s.ae_s.m_s.a...     family
# 4514               c.family_c.other_y.aend_s.ae_s.n_s.d        and
# 4515          c.and_c.people_y.ah_y.dher_s.ah_s.dh_s.er      other
# 4516     c.other_c.i_y.piy_y.pahl_s.p_s.iy_s.p_s.ah_s.l     people
# 4517                         c.people_c.think_y.ay_s.ay          i
# 4518          c.i_c.that's_y.thihngk_s.th_s.ih_s.ng_s.k      think
# 4519     c.think_c.important_y.dhaets_s.dh_s.ae_s.t_s.s     that's
# 4520  c.that's_c.if_y.ihm_y.paor_y.tahnt_s.ih_s.m_s....  important
# 4521                    c.important_c.he_y.ihf_s.ih_s.f         if
# 4522                      c.if_c.wants_y.hhiy_s.hh_s.iy         he
# 4523            c.he_c.to_y.waants_s.w_s.aa_s.n_s.t_s.s      wants
# 4524                        c.wants_c.be_y.tah_s.t_s.ah         to
# 4525                     c.to_c.catholic_y.biy_s.b_s.iy         be
# 4526  c.be_c.great_y.kaeth_y.lihk_s.k_s.ae_s.th_s.l_...   catholic
# 4527           c.catholic_c.if_y.greyt_s.g_s.r_s.ey_s.t      great
# 4528                        c.great_c.he_y.ihf_s.ih_s.f         if
# 4529                    c.if_c.doesn't_y.hhiy_s.hh_s.iy         he
# 4530        c.he_c.that's_y.dahsnt_s.d_s.ah_s.s_s.n_s.t    doesn't
# 4531        c.doesn't_c.okay_y.dhaets_s.dh_s.ae_s.t_s.s     that's
# 4532            c.that's_c.too_y.ow_y.key_s.ow_s.k_s.ey       okay
# 4533                       c.okay_c.okay_y.tuw_s.t_s.uw        too
# 4534              c.too_c.okay_y.ow_y.key_s.ow_s.k_s.ey       okay
# 4535                    c.okay_y.ow_y.key_s.ow_s.k_s.ey       okay
#
# [4536 rows x 2 columns]

# %%
## Fix event files by making them actuall tsv and removing the index column.

path = '/gpfs/project/anste145/input_files/buckeye_data/updated_eventfiles/'
all_ = []

for file in os.listdir(path):
    df = pd.read_csv(path + file, 
                  low_memory = True, 
                  dtype = ({'outcomes':'category'}), 
                  engine = 'c',
                  sep = '\t')
    df = df.drop(columns='Unnamed: 0')
    df.to_csv('/gpfs/project/anste145/input_files/buckeye_data/updated_eventfiles/' + file, sep = '\t', index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-14efb24ff1a3> in <module>
#      14 big_df = pd.concat(all_)
#      15 concat_w = big_df['outcomes'].tolist()
# ---> 16 missing = [w for w in regr_w if w not in concat_w]
#      17 len(missing)
#
# NameError: name 'regr_w' is not defined

# %%
## Merging the individual files again.

path = '/gpfs/project/anste145/input_files/buckeye_data/updated_eventfiles/'
all_ = []

for file in os.listdir(path):
    df = pd.read_csv(path + file, 
                  low_memory = True, 
                  dtype = ({'outcomes':'category'}), 
                  engine = 'c',
                  sep = '\t')
    all_.append(df)
    
big_df = pd.concat(all_)
concat_w = big_df['outcomes'].tolist()

# %%
## Testing if any words are missing. 

regression_words = pd.read_csv('/gpfs/project/anste145/input_files/buckeye_data/regression_data.csv', 
                              usecols = ['wordID'], 
                              dtype = ({'wordID': 'category'}),
                              engine = 'c', 
                              low_memory = True)
regr_w = regression_words['wordID'].tolist()
missing = [w for w in regr_w if w not in concat_w]
len(missing)
# --> No words are missing.
# Out:
# 0

# %%
## Writing final event file to file and creating a gzipped version for running the NDL model. 

big_df.to_csv('/gpfs/project/anste145/input_files/buckeye_data/final_eventfile_buckeye.tsv', sep = '\t', index = False)

with open('/gpfs/project/anste145/input_files/buckeye_data/final_eventfile_buckeye.tsv', 'rb') as f: 
    with gzip.open('/gpfs/project/anste145/input_files/buckeye_data/final_eventfile_buckeye.gz', 'wb') as output:
        shutil.copyfileobj(f,output)
